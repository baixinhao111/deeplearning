# %% [markdown]
# # 6.5 BatchNorm

# %% [markdown]
# ### 导入utils中的辅助函数

# %%
from utils import *

# %% [markdown]
# ## 读入猫狗数据

# %%
# %ls /course161/data/CatDog
# %ls /course161/data/CatDog/train
# %ls /course161/data/CatDog/validation
# Out:
# train/  validation/
# cats/  dogs/
# cats/  dogs/

# %%
batch_size = 32 # 指定batch_size 
IMSIZE = 128

data_dir = '/course161/data/CatDog' # 指定图片路径

# 将读入的图片resize后，转换成tensor
transform = transforms.Compose([
    transforms.Resize((IMSIZE, IMSIZE)), 
    transforms.ToTensor(), 
])

# 准备dataset，使用torchvision.datasets.ImageFolder读入图片，指定变换形式
train_set = torchvision.datasets.ImageFolder(root=os.path.join(data_dir, 'train'), transform=transform)
val_set = torchvision.datasets.ImageFolder(root=os.path.join(data_dir, 'validation'), transform=transform)
# 准备dataloaer

train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4)  # 进行打乱
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
from matplotlib import pyplot as plt
from torchvision.utils import make_grid
images, labels = next(iter(train_loader))  # 获取训练集第一个批次中的图片及相应标签
print(images.shape)
print(labels.shape)
plt.figure(figsize=(12, 6))  # 设置画布大小
plt.axis('off')  # 隐藏坐标轴
plt.imshow(make_grid(images, nrow=8).permute((1, 2, 0)))  # make_grid函数把多张图片一起显示，permute函数调换channel维的顺序
plt.show()
# Out:
# torch.Size([32, 3, 128, 128])
# torch.Size([32])

# %% [markdown]
# 借助PyTorch内置的nn.Sequential类构建模型。

# %% [markdown]
# ## 宽模型

# %%
class WideModel(nn.Module):
    def __init__(self):
        super(WideModel, self).__init__() 
        # 构建卷积层
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 100, kernel_size=2),  
            nn.BatchNorm2d(100),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=16))     

        # 构建全连接层 
        self.fc = nn.Sequential(
            nn.Linear(4900, 2)
        )
    # 前向计算流程
    def forward(self, x):
        out = self.cnn(x)
        out = out.view(out.size()[0], -1)  ## 在卷积操作后，输出仍是tensor，需要进行flatten拉直，再接全连接层
        out = self.fc(out)
        return out

# %%
# 验证模型是否构建正确
def test():
    X = torch.randn((1, 3, IMSIZE, IMSIZE))
    net = WideModel()
    out = net(X)
    print(out.shape)
    
test()
# Out:
# torch.Size([1, 2])

# %%
from torchsummary import summary
## 需要预先下载，在终端输入 pip install torchsummary
wide_model = WideModel().cuda()
summary(wide_model, (3, IMSIZE, IMSIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [-1, 100, 127, 127]           1,300
#        BatchNorm2d-2        [-1, 100, 127, 127]             200
#               ReLU-3        [-1, 100, 127, 127]               0
#          MaxPool2d-4            [-1, 100, 7, 7]               0
#             Linear-5                    [-1, 2]           9,802
# ================================================================
# Total params: 11,302
# Trainable params: 11,302
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 36.95
# Params size (MB): 0.04
# Estimated Total Size (MB): 37.18
# ----------------------------------------------------------------

# %% [markdown]
# ## 模型训练

# %% [markdown]
# 先定义几个训练中会用到的函数。

# %% [markdown]
# 输入参数epochs和lr，实施训练。

# %%
lr = 1e-3
optimizer = torch.optim.Adam(wide_model.parameters(), lr=lr)  # 设置优化器
epochs = 10
history = train(wide_model, optimizer, train_loader, val_loader, epochs=epochs)  # 实施训练
# Out:
# Epoch [1/10], time: 28.45s, loss: 0.7043, acc: 0.6620, val_loss: 0.8357, val_acc: 0.6005
# Epoch [2/10], time: 24.63s, loss: 0.5391, acc: 0.7424, val_loss: 0.5038, val_acc: 0.7569
# Epoch [3/10], time: 24.55s, loss: 0.5040, acc: 0.7605, val_loss: 0.5019, val_acc: 0.7517
# Epoch [5/10], time: 25.04s, loss: 0.4774, acc: 0.7715, val_loss: 0.4763, val_acc: 0.7682
# Epoch [6/10], time: 24.74s, loss: 0.4620, acc: 0.7863, val_loss: 0.5235, val_acc: 0.7576
# Epoch [7/10], time: 25.97s, loss: 0.4547, acc: 0.7877, val_loss: 0.5054, val_acc: 0.7538
# Epoch [8/10], time: 24.63s, loss: 0.4468, acc: 0.7930, val_loss: 0.4743, val_acc: 0.7794
# Epoch [9/10], time: 24.43s, loss: 0.4418, acc: 0.7948, val_loss: 0.4710, val_acc: 0.7818
# Epoch [10/10], time: 26.97s, loss: 0.4368, acc: 0.7966, val_loss: 0.4662, val_acc: 0.7808

# %% [markdown]
# ## 深模型

# %%
class DeepModel(nn.Module):
    def __init__(self):
        super(DeepModel, self).__init__() 
        ## 构建卷积层
        layers = []
        # 建立7层模型，每层结构相同
        for i in range(7):
            in_planes = 3 if i == 0 else 20 # 除了第一层输入为3，其余输入为20（卷积个数）
            layers += [nn.Conv2d(in_planes, 20, kernel_size=2, padding=1),
                                         nn.BatchNorm2d(20), # BN
                                         nn.ReLU(), # 非线性变换
                                         nn.MaxPool2d(kernel_size=2)] #池化
        self.cnn = nn.Sequential(*layers) # 将7层通过nn.Sequential连接起来

        # 构建全连接层 
        self.fc = nn.Sequential(
            nn.Linear(20, 2)
        )
    # 前向计算流程
    def forward(self, x):
        out = self.cnn(x)
        out = out.view(out.size()[0], -1)  ## 在卷积操作后，输出仍是tensor，需要进行flatten拉直，再接全连接层
        out = self.fc(out)
        return out

# %%
def test():
    X = torch.randn((1, 3, IMSIZE, IMSIZE))
    net = DeepModel()
    out = net(X)
    print(out.shape)
    
test()
# Out:
# torch.Size([1, 2])

# %%
deep_model = DeepModel().cuda()
summary(deep_model, (3, IMSIZE, IMSIZE))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 20, 129, 129]             260
#        BatchNorm2d-2         [-1, 20, 129, 129]              40
#               ReLU-3         [-1, 20, 129, 129]               0
#          MaxPool2d-4           [-1, 20, 64, 64]               0
#             Conv2d-5           [-1, 20, 65, 65]           1,620
#        BatchNorm2d-6           [-1, 20, 65, 65]              40
#               ReLU-7           [-1, 20, 65, 65]               0
#          MaxPool2d-8           [-1, 20, 32, 32]               0
#             Conv2d-9           [-1, 20, 33, 33]           1,620
#       BatchNorm2d-10           [-1, 20, 33, 33]              40
#              ReLU-11           [-1, 20, 33, 33]               0
#         MaxPool2d-12           [-1, 20, 16, 16]               0
#            Conv2d-13           [-1, 20, 17, 17]           1,620
#       BatchNorm2d-14           [-1, 20, 17, 17]              40
#              ReLU-15           [-1, 20, 17, 17]               0
#         MaxPool2d-16             [-1, 20, 8, 8]               0
#            Conv2d-17             [-1, 20, 9, 9]           1,620
#       BatchNorm2d-18             [-1, 20, 9, 9]              40
#              ReLU-19             [-1, 20, 9, 9]               0
#         MaxPool2d-20             [-1, 20, 4, 4]               0
#            Conv2d-21             [-1, 20, 5, 5]           1,620
#       BatchNorm2d-22             [-1, 20, 5, 5]              40
#              ReLU-23             [-1, 20, 5, 5]               0
#         MaxPool2d-24             [-1, 20, 2, 2]               0
#            Conv2d-25             [-1, 20, 3, 3]           1,620
#       BatchNorm2d-26             [-1, 20, 3, 3]              40
#              ReLU-27             [-1, 20, 3, 3]               0
#         MaxPool2d-28             [-1, 20, 1, 1]               0
#            Linear-29                    [-1, 2]              42
# ================================================================
# Total params: 10,302
# Trainable params: 10,302
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 11.07
# Params size (MB): 0.04
# Estimated Total Size (MB): 11.30
# ----------------------------------------------------------------

# %%
lr = 1e-3
optimizer = torch.optim.Adam(deep_model.parameters(), lr=lr)  # 设置优化器
history = train(deep_model, optimizer, train_loader, val_loader, epochs=epochs)  # 实施训练
# Out:
# Epoch [1/10], time: 25.06s, loss: 0.5970, acc: 0.6733, val_loss: 0.5308, val_acc: 0.7399
# Epoch [2/10], time: 24.65s, loss: 0.5400, acc: 0.7305, val_loss: 0.5153, val_acc: 0.7423
# Epoch [3/10], time: 27.91s, loss: 0.4811, acc: 0.7736, val_loss: 0.4632, val_acc: 0.7768
# Epoch [4/10], time: 24.89s, loss: 0.4463, acc: 0.7922, val_loss: 0.4458, val_acc: 0.7954
# Epoch [5/10], time: 24.68s, loss: 0.4212, acc: 0.8057, val_loss: 0.4266, val_acc: 0.7999
# Epoch [6/10], time: 25.88s, loss: 0.3923, acc: 0.8258, val_loss: 0.4153, val_acc: 0.8043
# Epoch [7/10], time: 24.86s, loss: 0.3746, acc: 0.8342, val_loss: 0.4189, val_acc: 0.8083
# Epoch [8/10], time: 25.06s, loss: 0.3576, acc: 0.8447, val_loss: 0.3939, val_acc: 0.8220
# Epoch [9/10], time: 26.95s, loss: 0.3384, acc: 0.8483, val_loss: 0.4007, val_acc: 0.8195
# Epoch [10/10], time: 24.82s, loss: 0.3296, acc: 0.8563, val_loss: 0.4004, val_acc: 0.8189
