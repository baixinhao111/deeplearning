# %% [markdown]
# # 6.6 DataAugmentation

# %% [markdown]
# ### 导入utils中的辅助函数

# %%
from utils import *

# %% [markdown]
# ## 读入猫狗数据

# %%
# %ls /course161/data/CatDog
# %ls /course161/data/CatDog/train
# %ls /course161/data/CatDog/validation
# Out:
# train/  validation/
# cats/  dogs/
# cats/  dogs/

# %%
batch_size = 10 # 指定batch_size 
IMSIZE = 128
data_dir = '/course161/data/CatDog' # 指定图片路径

# %% [markdown]
# ## 数据准备

# %%
# 测试集无需数据增强，将读入的图片resize后，转换成tensor
val_transform = transforms.Compose([
    transforms.Resize((IMSIZE, IMSIZE)), 
    transforms.ToTensor()
])

# %%
# 训练集进行数据增强
train_transform = transforms.Compose([
    transforms.Resize((IMSIZE, IMSIZE)), # Resize成规定尺寸
    transforms.RandomCrop(IMSIZE, padding=8), # 随机裁剪
    transforms.RandomHorizontalFlip(), # 水平翻转
    transforms.ToTensor()
])

# %%
# 准备dataset，使用torchvision.datasets.ImageFolder读入图片，指定变换形式
train_set = torchvision.datasets.ImageFolder(root=os.path.join(data_dir, 'train'), transform=train_transform)
val_set = torchvision.datasets.ImageFolder(root=os.path.join(data_dir,'validation'), transform=val_transform)
# 准备dataloaer
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle=False, num_workers=4)  # 进行打乱
val_loader = torch.utils.data.DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
from matplotlib import pyplot as plt
from torchvision.utils import make_grid
images, labels = next(iter(train_loader))  # 获取训练集第一个批次中的图片及相应标签
print(images.shape)
print(labels.shape)
plt.figure(figsize=(12, 6))  # 设置画布大小
plt.axis('off')  # 隐藏坐标轴
plt.imshow(make_grid(images, nrow=5).permute((1, 2, 0)))  # make_grid函数把多张图片一起显示，permute函数调换channel维的顺序
plt.show()
# Out:
# torch.Size([10, 3, 128, 128])
# torch.Size([10])

# %% [markdown]
# 借助PyTorch内置的nn.Sequential类构建模型。

# %% [markdown]
# ## 深模型

# %%
class DeepModel(nn.Module):
    def __init__(self):
        super(DeepModel, self).__init__() 
        ## 构建卷积层
        layers = []
        # 建立7层模型，每层结构相同
        for i in range(7):
            in_planes = 3 if i == 0 else 20 # 除了第一层输入为3，其余输入为20（卷积个数）
            layers += [nn.Conv2d(in_planes, 20, kernel_size=2, padding=1),
                                         nn.BatchNorm2d(20), # BN
                                         nn.ReLU(), # 非线性变换
                                         nn.MaxPool2d(kernel_size=2)] #池化
        self.cnn = nn.Sequential(*layers) # 将7层通过nn.Sequential连接起来
        # 构建全连接层 
        self.fc = nn.Sequential(
            nn.Linear(20, 2)
        )
    # 前向计算流程
    def forward(self, x):
        out = self.cnn(x)
        out = out.view(out.size()[0], -1)  # 在卷积操作后，输出仍是tensor，需要进行flatten拉直，再接全连接层
        out = self.fc(out)
        return out

# %%
def test():
    X = torch.randn((1, 3, IMSIZE, IMSIZE))
    net = DeepModel()
    out = net(X)
    print(out.shape)
    
test()
# Out:
# torch.Size([1, 2])

# %%
deep_model = DeepModel().cuda()
lr = 1e-3
optimizer = torch.optim.Adam(deep_model.parameters(), lr=lr)  # 设置优化器
epochs = 10
history = train(deep_model, optimizer, train_loader, val_loader, epochs=epochs)  # 实施训练
# Out:
# Epoch [1/10], time: 31.49s, loss: 0.0424, acc: 0.9918, val_loss: 3.5516, val_acc: 0.5000
# Epoch [2/10], time: 26.41s, loss: 0.3527, acc: 0.9851, val_loss: 18.0010, val_acc: 0.5000
# Epoch [3/10], time: 26.48s, loss: 0.1263, acc: 0.9786, val_loss: 9.9660, val_acc: 0.5000
# Epoch [4/10], time: 25.94s, loss: 0.0844, acc: 0.9881, val_loss: 5.6581, val_acc: 0.5000
# Epoch [5/10], time: 26.57s, loss: 0.0984, acc: 0.9781, val_loss: 8.6392, val_acc: 0.5000
# Epoch [6/10], time: 29.10s, loss: 0.1054, acc: 0.9793, val_loss: 5.0709, val_acc: 0.5000
# Epoch [7/10], time: 26.41s, loss: 0.1086, acc: 0.9720, val_loss: 5.3471, val_acc: 0.5000
# Epoch [8/10], time: 25.92s, loss: 0.1376, acc: 0.9600, val_loss: 4.5161, val_acc: 0.5000
# Epoch [9/10], time: 28.62s, loss: 0.1715, acc: 0.9500, val_loss: 5.4162, val_acc: 0.5000
# Epoch [10/10], time: 26.37s, loss: 0.1472, acc: 0.9607, val_loss: 4.4826, val_acc: 0.5000
